# %% [markdown]
# # Upload sequencing data to SRA
# This Python Jupyter notebook uploads the sequencing data to the NIH [Sequence Read Archive](https://www.ncbi.nlm.nih.gov/sra), or SRA.

# %% [markdown]
# ## Create BioProject and BioSamples
# The first step was done manually to create the BioProject and BioSamples.
# Note that for new future uploads related to the RBD DMS, you may be able to use the existing BioProject, but since this is the first entries in these project I needed to create a new BioProject.
#
# To create these, I went to the [Sequence Read Archive](https://www.ncbi.nlm.nih.gov/sra) and signed in using the box at the upper right of the webpage, and then went to the [SRA Submission Portal](https://submit.ncbi.nlm.nih.gov/subs/sra/).
# I then manually completed the first five steps, which define the project and samples.

# %% [markdown]
# ## Create submission sheet
# The sixth step is to create the submission sheet in `*.tsv` format, which is done by the following code.
#
# First, import Python modules:

# %%
import ftplib
import os
import tarfile
import datetime

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Read the configuration for the analysis:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the PacBio runs:

# %%
pacbio_runs_file = os.path.join('./', 'pacbio_runs_to_upload.csv')

print(f"Reading PacBio runs from {pacbio_runs_file}")

pacbio_runs = (
    pd.read_csv(pacbio_runs_file)
#     .assign(ccs_file=lambda x: f"../{config['ccs_dir']}/" + x['library'] + '_' + x['run'] + '_ccs.fastq.gz')
    .assign(ccs_file=lambda x: x['ccs'])
    )

pacbio_runs.head()
# Out:
# Reading PacBio runs from ./pacbio_runs_to_upload.csv
#   library          bg       run  \
# 0   pool1  Wuhan_Hu_1  210701_A
# 1   pool2  Wuhan_Hu_1  210701_A
# 2   pool1       E484K  210701_A
# 3   pool2       E484K  210701_A
# 4   pool1       N501Y  210701_A
#
#                                                  ccs  \
# 0  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 1  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 2  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 3  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 4  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
#
#                                             ccs_file
# 0  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 1  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 2  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 3  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 4  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...

# %% [markdown]
# Next make submission entries for the PacBio CCSs:

# %%
pacbio_submissions = (
    pacbio_runs
    .assign(
        biosample_accession='SAMN25941479',
        library_ID=lambda x: x['bg'] + '_' + x['library'] + '_PacBio_CCSs',  # unique library ID
        title='PacBio CCSs linking variants to barcodes for SARS-CoV-2 variant RBD deep mutational scanning',
        library_strategy='Synthetic-Long-Read',
        library_source='SYNTHETIC',
        library_selection='Restriction Digest',
        library_layout='single',
        platform='PACBIO_SMRT',
        instrument_model='PacBio Sequel II',
        design_description='Restriction digest of plasmids carrying barcoded RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['ccs_file'],      
        )
    .drop(columns=pacbio_runs.columns)
    )

pacbio_submissions.head()
# Out:
#   biosample_accession                    library_ID  \
# 0        SAMN25941479  Wuhan_Hu_1_pool1_PacBio_CCSs
# 1        SAMN25941479  Wuhan_Hu_1_pool2_PacBio_CCSs
# 2        SAMN25941479       E484K_pool1_PacBio_CCSs
# 3        SAMN25941479       E484K_pool2_PacBio_CCSs
# 4        SAMN25941479       N501Y_pool1_PacBio_CCSs
#
#                                                title     library_strategy  \
# 0  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 1  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 2  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 3  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 4  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
#
#   library_source   library_selection library_layout     platform  \
# 0      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 1      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 2      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 3      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 4      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
#
#    instrument_model                                 design_description  \
# 0  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 1  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 2  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 3  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 4  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
#
#   filetype                                  filename_fullpath
# 0    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 1    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 2    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 3    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 4    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...

# %% [markdown]
# Now concatenate the PacBio submissions into tidy format (one line per file), make sure all the files exist.

# %%
submissions_tidy = (
    pd.concat([pacbio_submissions], ignore_index=True)
    .assign(file_exists=lambda x: x['filename_fullpath'].map(os.path.isfile),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename),
            )
    )

assert submissions_tidy['file_exists'].all(), submissions_tidy.query('file_exists == False')

submissions_tidy.head()
# Out:
#   biosample_accession                    library_ID  \
# 0        SAMN25941479  Wuhan_Hu_1_pool1_PacBio_CCSs
# 1        SAMN25941479  Wuhan_Hu_1_pool2_PacBio_CCSs
# 2        SAMN25941479       E484K_pool1_PacBio_CCSs
# 3        SAMN25941479       E484K_pool2_PacBio_CCSs
# 4        SAMN25941479       N501Y_pool1_PacBio_CCSs
#
#                                                title     library_strategy  \
# 0  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 1  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 2  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 3  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 4  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
#
#   library_source   library_selection library_layout     platform  \
# 0      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 1      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 2      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 3      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 4      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
#
#    instrument_model                                 design_description  \
# 0  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 1  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 2  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 3  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 4  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
#
#   filetype                                  filename_fullpath  file_exists  \
# 0    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...         True
# 1    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...         True
# 2    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...         True
# 3    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...         True
# 4    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...         True
#
#                                             filename
# 0  demultiplex.bc1001_BAK8A_OA--bc1001_BAK8A_OA.h...
# 1  demultiplex.bc1011_BAK8A_OA--bc1011_BAK8A_OA.h...
# 2  demultiplex.bc1012_BAK8A_OA--bc1012_BAK8A_OA.h...
# 3  demultiplex.bc1018_BAK8B_OA--bc1018_BAK8B_OA.h...
# 4  demultiplex.bc1019_BAK8B_OA--bc1019_BAK8B_OA.h...

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['biosample_accession', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#   biosample_accession                    library_ID  n_files
# 0        SAMN25941479       N501Y_pool1_PacBio_CCSs        3
# 1        SAMN25941479  Wuhan_Hu_1_pool1_PacBio_CCSs        3
# 2        SAMN25941479       Delta_pool1_PacBio_CCSs        1
# 3        SAMN25941479       Delta_pool2_PacBio_CCSs        1
# 4        SAMN25941479       E484K_pool1_PacBio_CCSs        1
# 5        SAMN25941479       E484K_pool2_PacBio_CCSs        1
# 6        SAMN25941479       N501Y_pool2_PacBio_CCSs        1
# 7        SAMN25941479  Wuhan_Hu_1_pool2_PacBio_CCSs        1

# %% [markdown]
# Now make the wide submission data frame.

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['biosample_accession', 'library_ID'])['filename_fullpath'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename_fullpath',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'file_exists', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

submissions_wide
# Out:
#   biosample_accession                    library_ID  \
# 0        SAMN25941479  Wuhan_Hu_1_pool1_PacBio_CCSs
# 1        SAMN25941479  Wuhan_Hu_1_pool2_PacBio_CCSs
# 2        SAMN25941479       E484K_pool1_PacBio_CCSs
# 3        SAMN25941479       E484K_pool2_PacBio_CCSs
# 4        SAMN25941479       N501Y_pool1_PacBio_CCSs
# 5        SAMN25941479       N501Y_pool2_PacBio_CCSs
# 6        SAMN25941479       Delta_pool1_PacBio_CCSs
# 7        SAMN25941479       Delta_pool2_PacBio_CCSs
#
#                                                title     library_strategy  \
# 0  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 1  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 2  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 3  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 4  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 5  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 6  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
# 7  PacBio CCSs linking variants to barcodes for S...  Synthetic-Long-Read
#
#   library_source   library_selection library_layout     platform  \
# 0      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 1      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 2      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 3      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 4      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 5      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 6      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
# 7      SYNTHETIC  Restriction Digest         single  PACBIO_SMRT
#
#    instrument_model                                 design_description  \
# 0  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 1  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 2  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 3  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 4  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 5  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 6  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
# 7  PacBio Sequel II  Restriction digest of plasmids carrying barcod...
#
#   filetype                                           filename  \
# 0    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 1    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 2    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 3    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 4    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 5    fastq  /fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Gre...
# 6    fastq  /fh/fast/bloom_j/SR/ngs/pacbio/211026_SequelII...
# 7    fastq  /fh/fast/bloom_j/SR/ngs/pacbio/211026_SequelII...
#
#                                            filename2  \
# 0  /fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerSta...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  /fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerSta...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                                            filename3
# 0  /fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerSta...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  /fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerSta...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# This submission sheet was then manually uploaded in Step 6 of the SRA submission wizard (*SRA metadata*).

# %% [markdown]
# ## Upload the actual files
# Step 7 of the SRA submission wizard is to upload the files.
# In order to do this, we first make a `*.tar` file with all of the files.
# Since this takes a long time, we only create the file if it doesn't already exist, so it is only created the first time this notebook is run.
# **Note that this will cause a problem if you add more sequencing files to upload after running the notebook, in that case the cell below will need to altered.**

# %%
tar_filename = 'SRA_submission.tar'

if os.path.isfile(tar_filename):
    print(f"{tar_filename} already exists, not creating it again")
else:
    try:
        with tarfile.open(tar_filename, mode='w') as f:
            for i, tup in enumerate(submissions_tidy.itertuples()):
                print(f"Adding file {i + 1} of {len(submissions_tidy)} to {tar_filename}")
                f.add(tup.filename_fullpath, arcname=tup.filename_fullpath)
            print(f"Added all files to {tar_filename}")
    except:
        if os.path.isfile(tar_filename):
            os.remove(tar_filename)
        raise
# Out:
# SRA_submission.tar already exists, not creating it again

# %% [markdown]
# See the size of the `*.tar` file to upload and make sure it has the expected files:
#
# Note: the filenames in the `*.tar` file lack the initial backslash, but i confirmed manually that all are present

# %%
print(f"The size of {tar_filename} is {os.path.getsize(tar_filename) / 1e9:.1f} GB")

with tarfile.open(tar_filename) as f:
    files_in_tar = set(f.getnames())
    print(files_in_tar)
    print(set(submissions_tidy['filename_fullpath']))
#if files_in_tar == set(submissions_tidy['filename_fullpath']):
#    print(f"{tar_filename} contains all {len(files_in_tar)} expected files.")
#else:
#    raise ValueError(f"{tar_filename} does not have all the expected files.")
# Out:
# The size of SRA_submission.tar is 2.0 GB
# {'fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell1/demultiplex.bc1001_BAK8A_OA--bc1001_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1011_BAK8A_OA--bc1011_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell2/demultiplex.bc1001_BAK8A_OA--bc1001_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1020_BAK8B_OA--bc1020_BAK8B_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio/211026_SequelIIe/Allie_Pool-Cell2/demultiplex.bc1009_BAK8A_OA--bc1009_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1012_BAK8A_OA--bc1012_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1001_BAK8A_OA--bc1001_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1018_BAK8B_OA--bc1018_BAK8B_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell2/demultiplex.bc1002_BAK8A_OA--bc1002_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1019_BAK8B_OA--bc1019_BAK8B_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell1/demultiplex.bc1002_BAK8A_OA--bc1002_BAK8A_OA.hifi_reads.fastq.gz', 'fh/fast/bloom_j/SR/ngs/pacbio/211026_SequelIIe/Allie_Pool-Cell2/demultiplex.bc1010_BAK8A_OA--bc1010_BAK8A_OA.hifi_reads.fastq.gz'}
# {'/fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1001_BAK8A_OA--bc1001_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell2/demultiplex.bc1001_BAK8A_OA--bc1001_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell1/demultiplex.bc1001_BAK8A_OA--bc1001_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1018_BAK8B_OA--bc1018_BAK8B_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell1/demultiplex.bc1002_BAK8A_OA--bc1002_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio/211026_SequelIIe/Allie_Pool-Cell2/demultiplex.bc1010_BAK8A_OA--bc1010_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1020_BAK8B_OA--bc1020_BAK8B_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio/211026_SequelIIe/Allie_Pool-Cell2/demultiplex.bc1009_BAK8A_OA--bc1009_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1011_BAK8A_OA--bc1011_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1019_BAK8B_OA--bc1019_BAK8B_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio/211118_TylerStarr/211108_pool_Starr-Cell2/demultiplex.bc1002_BAK8A_OA--bc1002_BAK8A_OA.hifi_reads.fastq.gz', '/fh/fast/bloom_j/SR/ngs/pacbio_UW/20210701_Greaney_A/bg_pool.AG/CCS_7555/fastx_files/demultiplex.bc1012_BAK8A_OA--bc1012_BAK8A_OA.hifi_reads.fastq.gz'}

# %% [markdown]
# The SRA instructions then give several ways to upload; we will do it using the FTP method.
# First, specify the FTP address, username, password, and subfolder given by the SRA submission wizard instructions.
# In order to avoid having the password be public here, that is in a separate text file that is **not** included in the GitHub repo (so this needs to be run in Tyler's directory that has this password):

# %%
# the following are provided by SRA wizard insturctions
ftp_address = 'ftp-private.ncbi.nlm.nih.gov'
ftp_username = 'subftp'
ftp_account_folder = 'uploads/tyler.n.starr_gmail.com_LMpRB4Tu'
with open('ftp_password.txt') as f:
    ftp_password = f.read().strip()
    
# meaningful name for subfolder
ftp_subfolder = 'variant_RBD_barcode_association_take2'

# %% [markdown]
# Now create FTP connection and upload the TAR file.
# Note that this takes a while.
# If you are worried that it will timeout given the size of your file, you can run this notebook via `slurm` so there is no timing out:

# %%
print(f"Starting upload at {datetime.datetime.now()}")

with ftplib.FTP(ftp_address) as ftp:
    ftp.login(user=ftp_username,
              passwd=ftp_password,
              )
    ftp.cwd(ftp_account_folder)
    ftp.mkd(ftp_subfolder)
    ftp.cwd(ftp_subfolder)
    with open(tar_filename, 'rb') as f:
        ftp.storbinary(f"STOR {tar_filename}", f)
        
print(f"Finished upload at {datetime.datetime.now()}")
# Out:
# Starting upload at 2022-02-14 13:14:37.340561
# Finished upload at 2022-02-14 13:40:28.585055

# %% [markdown]
# Finally, used the SRA wizard to select the `*.tar` archive and complete the submission.
# Note that there is a warning of missing files since everything was uploaded as a `*.tar` rather than individual files.
# They should all be found when you hit the button to proceed and the `*.tar` is unpacked.
#
# There was then a message that the submission was processing, and data would be released immediately upon processing.
# The submission number is `SUB11087053`.
