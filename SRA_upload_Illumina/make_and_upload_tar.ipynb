# %% [markdown]
# # Create TAR file of FASTQs and upload to SRA
# This Python Jupyter notebook creates a `*.tar` file of the FASTQs and uploads them to the SRA.
#
# First, import Python modules:

# %%
import datetime
import ftplib
import os
import tarfile

import pandas as pd

import yaml

# %% [markdown]
# Read in the FASTQ files to upload:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)
    
fastqs = pd.read_csv('FASTQs_to_upload.csv')

# %% [markdown]
# Now we need to make a `*.tar` file with all of the files.
# Note that this step **will take a long time to run**.

# %%
tar_filename = 'SRA_submission.tar'

try:
    with tarfile.open(tar_filename, mode='w') as f:
        for i, tup in enumerate(fastqs.itertuples()):
            print(f"Adding file {i + 1} of {len(fastqs)} to {tar_filename}")
            f.add(tup.filename_fullpath, arcname=tup.filename)
        print(f"Added all files to {tar_filename}")
except:
    if os.path.isfile(tar_filename):
        os.remove(tar_filename)
    raise
# Out:
# Adding file 1 of 212 to SRA_submission.tar
# Adding file 2 of 212 to SRA_submission.tar
# Adding file 3 of 212 to SRA_submission.tar
# Adding file 4 of 212 to SRA_submission.tar
# Adding file 5 of 212 to SRA_submission.tar
# Adding file 6 of 212 to SRA_submission.tar
# Adding file 7 of 212 to SRA_submission.tar
# Adding file 8 of 212 to SRA_submission.tar
# Adding file 9 of 212 to SRA_submission.tar
# Adding file 10 of 212 to SRA_submission.tar
# Adding file 11 of 212 to SRA_submission.tar
# Adding file 12 of 212 to SRA_submission.tar
# Adding file 13 of 212 to SRA_submission.tar
# Adding file 14 of 212 to SRA_submission.tar
# Adding file 15 of 212 to SRA_submission.tar
# Adding file 16 of 212 to SRA_submission.tar
# Adding file 17 of 212 to SRA_submission.tar
# Adding file 18 of 212 to SRA_submission.tar
# Adding file 19 of 212 to SRA_submission.tar
# Adding file 20 of 212 to SRA_submission.tar
# Adding file 21 of 212 to SRA_submission.tar
# Adding file 22 of 212 to SRA_submission.tar
# Adding file 23 of 212 to SRA_submission.tar
# Adding file 24 of 212 to SRA_submission.tar
# Adding file 25 of 212 to SRA_submission.tar
# Adding file 26 of 212 to SRA_submission.tar
# Adding file 27 of 212 to SRA_submission.tar
# Adding file 28 of 212 to SRA_submission.tar
# Adding file 29 of 212 to SRA_submission.tar
# Adding file 30 of 212 to SRA_submission.tar
# Adding file 31 of 212 to SRA_submission.tar
# Adding file 32 of 212 to SRA_submission.tar
# Adding file 33 of 212 to SRA_submission.tar
# Adding file 34 of 212 to SRA_submission.tar
# Adding file 35 of 212 to SRA_submission.tar
# Adding file 36 of 212 to SRA_submission.tar
# Adding file 37 of 212 to SRA_submission.tar
# Adding file 38 of 212 to SRA_submission.tar
# Adding file 39 of 212 to SRA_submission.tar
# Adding file 40 of 212 to SRA_submission.tar
# Adding file 41 of 212 to SRA_submission.tar
# Adding file 42 of 212 to SRA_submission.tar
# Adding file 43 of 212 to SRA_submission.tar
# Adding file 44 of 212 to SRA_submission.tar
# Adding file 45 of 212 to SRA_submission.tar
# Adding file 46 of 212 to SRA_submission.tar
# Adding file 47 of 212 to SRA_submission.tar
# Adding file 48 of 212 to SRA_submission.tar
# Adding file 49 of 212 to SRA_submission.tar
# Adding file 50 of 212 to SRA_submission.tar
# Adding file 51 of 212 to SRA_submission.tar
# Adding file 52 of 212 to SRA_submission.tar
# Adding file 53 of 212 to SRA_submission.tar
# Adding file 54 of 212 to SRA_submission.tar
# Adding file 55 of 212 to SRA_submission.tar
# Adding file 56 of 212 to SRA_submission.tar
# Adding file 57 of 212 to SRA_submission.tar
# Adding file 58 of 212 to SRA_submission.tar
# Adding file 59 of 212 to SRA_submission.tar
# Adding file 60 of 212 to SRA_submission.tar
# Adding file 61 of 212 to SRA_submission.tar
# Adding file 62 of 212 to SRA_submission.tar
# Adding file 63 of 212 to SRA_submission.tar
# Adding file 64 of 212 to SRA_submission.tar
# Adding file 65 of 212 to SRA_submission.tar
# Adding file 66 of 212 to SRA_submission.tar
# Adding file 67 of 212 to SRA_submission.tar
# Adding file 68 of 212 to SRA_submission.tar
# Adding file 69 of 212 to SRA_submission.tar
# Adding file 70 of 212 to SRA_submission.tar
# Adding file 71 of 212 to SRA_submission.tar
# Adding file 72 of 212 to SRA_submission.tar
# Adding file 73 of 212 to SRA_submission.tar
# Adding file 74 of 212 to SRA_submission.tar
# Adding file 75 of 212 to SRA_submission.tar
# Adding file 76 of 212 to SRA_submission.tar
# Adding file 77 of 212 to SRA_submission.tar
# Adding file 78 of 212 to SRA_submission.tar
# Adding file 79 of 212 to SRA_submission.tar
# Adding file 80 of 212 to SRA_submission.tar
# Adding file 81 of 212 to SRA_submission.tar
# Adding file 82 of 212 to SRA_submission.tar
# Adding file 83 of 212 to SRA_submission.tar
# Adding file 84 of 212 to SRA_submission.tar
# Adding file 85 of 212 to SRA_submission.tar
# Adding file 86 of 212 to SRA_submission.tar
# Adding file 87 of 212 to SRA_submission.tar
# Adding file 88 of 212 to SRA_submission.tar
# Adding file 89 of 212 to SRA_submission.tar
# Adding file 90 of 212 to SRA_submission.tar
# Adding file 91 of 212 to SRA_submission.tar
# Adding file 92 of 212 to SRA_submission.tar
# Adding file 93 of 212 to SRA_submission.tar
# Adding file 94 of 212 to SRA_submission.tar
# Adding file 95 of 212 to SRA_submission.tar
# Adding file 96 of 212 to SRA_submission.tar
# Adding file 97 of 212 to SRA_submission.tar
# Adding file 98 of 212 to SRA_submission.tar
# Adding file 99 of 212 to SRA_submission.tar
# Adding file 100 of 212 to SRA_submission.tar
# Adding file 101 of 212 to SRA_submission.tar
# Adding file 102 of 212 to SRA_submission.tar
# Adding file 103 of 212 to SRA_submission.tar
# Adding file 104 of 212 to SRA_submission.tar
# Adding file 105 of 212 to SRA_submission.tar
# Adding file 106 of 212 to SRA_submission.tar
# Adding file 107 of 212 to SRA_submission.tar
# Adding file 108 of 212 to SRA_submission.tar
# Adding file 109 of 212 to SRA_submission.tar
# Adding file 110 of 212 to SRA_submission.tar
# Adding file 111 of 212 to SRA_submission.tar
# Adding file 112 of 212 to SRA_submission.tar
# Adding file 113 of 212 to SRA_submission.tar
# Adding file 114 of 212 to SRA_submission.tar
# Adding file 115 of 212 to SRA_submission.tar
# Adding file 116 of 212 to SRA_submission.tar
# Adding file 117 of 212 to SRA_submission.tar
# Adding file 118 of 212 to SRA_submission.tar
# Adding file 119 of 212 to SRA_submission.tar
# Adding file 120 of 212 to SRA_submission.tar
# Adding file 121 of 212 to SRA_submission.tar
# Adding file 122 of 212 to SRA_submission.tar
# Adding file 123 of 212 to SRA_submission.tar
# Adding file 124 of 212 to SRA_submission.tar
# Adding file 125 of 212 to SRA_submission.tar
# Adding file 126 of 212 to SRA_submission.tar
# Adding file 127 of 212 to SRA_submission.tar
# Adding file 128 of 212 to SRA_submission.tar
# Adding file 129 of 212 to SRA_submission.tar
# Adding file 130 of 212 to SRA_submission.tar
# Adding file 131 of 212 to SRA_submission.tar
# Adding file 132 of 212 to SRA_submission.tar
# Adding file 133 of 212 to SRA_submission.tar
# Adding file 134 of 212 to SRA_submission.tar
# Adding file 135 of 212 to SRA_submission.tar
# Adding file 136 of 212 to SRA_submission.tar
# Adding file 137 of 212 to SRA_submission.tar
# Adding file 138 of 212 to SRA_submission.tar
# Adding file 139 of 212 to SRA_submission.tar
# Adding file 140 of 212 to SRA_submission.tar
# Adding file 141 of 212 to SRA_submission.tar
# Adding file 142 of 212 to SRA_submission.tar
# Adding file 143 of 212 to SRA_submission.tar
# Adding file 144 of 212 to SRA_submission.tar
# Adding file 145 of 212 to SRA_submission.tar
# Adding file 146 of 212 to SRA_submission.tar
# Adding file 147 of 212 to SRA_submission.tar
# Adding file 148 of 212 to SRA_submission.tar
# Adding file 149 of 212 to SRA_submission.tar
# Adding file 150 of 212 to SRA_submission.tar
# Adding file 151 of 212 to SRA_submission.tar
# Adding file 152 of 212 to SRA_submission.tar
# Adding file 153 of 212 to SRA_submission.tar
# Adding file 154 of 212 to SRA_submission.tar
# Adding file 155 of 212 to SRA_submission.tar
# Adding file 156 of 212 to SRA_submission.tar
# Adding file 157 of 212 to SRA_submission.tar
# Adding file 158 of 212 to SRA_submission.tar
# Adding file 159 of 212 to SRA_submission.tar
# Adding file 160 of 212 to SRA_submission.tar
# Adding file 161 of 212 to SRA_submission.tar
# Adding file 162 of 212 to SRA_submission.tar
# Adding file 163 of 212 to SRA_submission.tar
# Adding file 164 of 212 to SRA_submission.tar
# Adding file 165 of 212 to SRA_submission.tar
# Adding file 166 of 212 to SRA_submission.tar
# Adding file 167 of 212 to SRA_submission.tar
# Adding file 168 of 212 to SRA_submission.tar
# Adding file 169 of 212 to SRA_submission.tar
# Adding file 170 of 212 to SRA_submission.tar
# Adding file 171 of 212 to SRA_submission.tar
# Adding file 172 of 212 to SRA_submission.tar
# Adding file 173 of 212 to SRA_submission.tar
# Adding file 174 of 212 to SRA_submission.tar
# Adding file 175 of 212 to SRA_submission.tar
# Adding file 176 of 212 to SRA_submission.tar
# Adding file 177 of 212 to SRA_submission.tar
# Adding file 178 of 212 to SRA_submission.tar
# Adding file 179 of 212 to SRA_submission.tar
# Adding file 180 of 212 to SRA_submission.tar
# Adding file 181 of 212 to SRA_submission.tar
# Adding file 182 of 212 to SRA_submission.tar
# Adding file 183 of 212 to SRA_submission.tar
# Adding file 184 of 212 to SRA_submission.tar
# Adding file 185 of 212 to SRA_submission.tar
# Adding file 186 of 212 to SRA_submission.tar
# Adding file 187 of 212 to SRA_submission.tar
# Adding file 188 of 212 to SRA_submission.tar
# Adding file 189 of 212 to SRA_submission.tar
# Adding file 190 of 212 to SRA_submission.tar
# Adding file 191 of 212 to SRA_submission.tar
# Adding file 192 of 212 to SRA_submission.tar
# Adding file 193 of 212 to SRA_submission.tar
# Adding file 194 of 212 to SRA_submission.tar
# Adding file 195 of 212 to SRA_submission.tar
# Adding file 196 of 212 to SRA_submission.tar
# Adding file 197 of 212 to SRA_submission.tar
# Adding file 198 of 212 to SRA_submission.tar
# Adding file 199 of 212 to SRA_submission.tar
# Adding file 200 of 212 to SRA_submission.tar
# Adding file 201 of 212 to SRA_submission.tar
# Adding file 202 of 212 to SRA_submission.tar
# Adding file 203 of 212 to SRA_submission.tar
# Adding file 204 of 212 to SRA_submission.tar
# Adding file 205 of 212 to SRA_submission.tar
# Adding file 206 of 212 to SRA_submission.tar
# Adding file 207 of 212 to SRA_submission.tar
# Adding file 208 of 212 to SRA_submission.tar
# Adding file 209 of 212 to SRA_submission.tar
# Adding file 210 of 212 to SRA_submission.tar
# Adding file 211 of 212 to SRA_submission.tar
# Adding file 212 of 212 to SRA_submission.tar
# Added all files to SRA_submission.tar

# %% [markdown]
# See the size of the `*.tar` file to upload and make sure it has the expected files:

# %%
print(f"The size of {tar_filename} is {os.path.getsize(tar_filename) / 1e9:.1f} GB")

with tarfile.open(tar_filename) as f:
    files_in_tar = set(f.getnames())
if files_in_tar == set(fastqs['filename']):
    print(f"{tar_filename} contains all {len(files_in_tar)} expected files.")
else:
    raise ValueError(f"{tar_filename} does not have all the expected files.")
# Out:
# The size of SRA_submission.tar is 16.6 GB
# SRA_submission.tar contains all 212 expected files.

# %% [markdown]
# We now read in the details about doing the FTP upload to the SRA.
# Note that these are set in separate files already:

# %%
# the following are provided by SRA wizard insturctions
ftp_address = 'ftp-private.ncbi.nlm.nih.gov'
ftp_username = config['ftp_username'].strip()
ftp_account_folder = config['ftp_account_folder'].strip()
ftp_subfolder = config['ftp_subfolder'].strip()
with open('ftp_password.txt') as f:
    ftp_password = f.read().strip()

# %% [markdown]
# Now create FTP connection and upload the TAR file.
# Note that this takes a while.
# If you are worried that it will timeout given the size of your file, you can run this notebook via `slurm` so there is no timing out:

# %%
print(f"Starting upload at {datetime.datetime.now()}")

with ftplib.FTP(ftp_address) as ftp:
    ftp.login(user=ftp_username,
              passwd=ftp_password,
              )
    ftp.cwd(ftp_account_folder)
    ftp.mkd(ftp_subfolder)
    ftp.cwd(ftp_subfolder)
    with open(tar_filename, 'rb') as f:
        ftp.storbinary(f"STOR {tar_filename}", f)
        
print(f"Finished upload at {datetime.datetime.now()}")
# Out:
# Starting upload at 2022-02-14 13:55:50.619789
# Finished upload at 2022-02-14 17:14:03.173040
